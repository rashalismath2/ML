# %%
import pandas as pd
from ucimlrepo import fetch_ucirepo 
from sklearn.model_selection import train_test_split

# %%
# fetch dataset 
communities_and_crime = fetch_ucirepo(id=183) 
  
# data (as pandas dataframes) 
X = communities_and_crime.data.features 
y = communities_and_crime.data.targets

# %%
X
# Out:
#       state county community        communityname  fold  population  \
# 0         8      ?         ?         Lakewoodcity     1        0.19
# 1        53      ?         ?          Tukwilacity     1        0.00
# 2        24      ?         ?         Aberdeentown     1        0.00
# 3        34      5     81440  Willingborotownship     1        0.04
# 4        42     95      6096    Bethlehemtownship     1        0.01
# ...     ...    ...       ...                  ...   ...         ...
# 1989     12      ?         ?    TempleTerracecity    10        0.01
# 1990      6      ?         ?          Seasidecity    10        0.05
# 1991      9      9     80070        Waterburytown    10        0.16
# 1992     25     17     72600          Walthamcity    10        0.08
# 1993      6      ?         ?          Ontariocity    10        0.20
#
#       householdsize  racepctblack  racePctWhite  racePctAsian  ...  \
# 0              0.33          0.02          0.90          0.12  ...
# 1              0.16          0.12          0.74          0.45  ...
# 2              0.42          0.49          0.56          0.17  ...
# 3              0.77          1.00          0.08          0.12  ...
# 4              0.55          0.02          0.95          0.09  ...
# ...             ...           ...           ...           ...  ...
# 1989           0.40          0.10          0.87          0.12  ...
# 1990           0.96          0.46          0.28          0.83  ...
# 1991           0.37          0.25          0.69          0.04  ...
# 1992           0.51          0.06          0.87          0.22  ...
# 1993           0.78          0.14          0.46          0.24  ...
#
#       PolicAveOTWorked  LandArea  PopDens  PctUsePubTrans  PolicCars  \
# 0                 0.29      0.12     0.26            0.20       0.06
# 1                    ?      0.02     0.12            0.45          ?
# 2                    ?      0.01     0.21            0.02          ?
# 3                    ?      0.02     0.39            0.28          ?
# 4                    ?      0.04     0.09            0.02          ?
# ...                ...       ...      ...             ...        ...
# 1989                 ?      0.01     0.28            0.05          ?
# 1990                 ?      0.02     0.37            0.20          ?
# 1991              0.25      0.08     0.32            0.18       0.08
# 1992              0.19      0.03     0.38            0.33       0.02
# 1993              0.11      0.11     0.30            0.05       0.08
#
#       PolicOperBudg  LemasPctPolicOnPatr  LemasGangUnitDeploy  \
# 0              0.04                  0.9                  0.5
# 1                 ?                    ?                    ?
# 2                 ?                    ?                    ?
# 3                 ?                    ?                    ?
# 4                 ?                    ?                    ?
# ...             ...                  ...                  ...
# 1989              ?                    ?                    ?
# 1990              ?                    ?                    ?
# 1991           0.06                 0.78                    0
# 1992           0.02                 0.79                    0
# 1993           0.04                 0.73                  0.5
#
#       LemasPctOfficDrugUn  PolicBudgPerPop
# 0                    0.32             0.14
# 1                    0.00                ?
# 2                    0.00                ?
# 3                    0.00                ?
# 4                    0.00                ?
# ...                   ...              ...
# 1989                 0.00                ?
# 1990                 0.00                ?
# 1991                 0.91             0.28
# 1992                 0.22             0.18
# 1993                 1.00             0.13
#
# [1994 rows x 127 columns]

# %%
X.describe(include='all')
# Out:
#               state county community   communityname         fold  \
# count   1994.000000   1994      1994            1994  1994.000000
# unique          NaN    109       800            1828          NaN
# top             NaN      ?         ?  Greenvillecity          NaN
# freq            NaN   1174      1177               5          NaN
# mean      28.683551    NaN       NaN             NaN     5.493982
# std       16.397553    NaN       NaN             NaN     2.873694
# min        1.000000    NaN       NaN             NaN     1.000000
# 25%       12.000000    NaN       NaN             NaN     3.000000
# 50%       34.000000    NaN       NaN             NaN     5.000000
# 75%       42.000000    NaN       NaN             NaN     8.000000
# max       56.000000    NaN       NaN             NaN    10.000000
#
#          population  householdsize  racepctblack  racePctWhite  racePctAsian  \
# count   1994.000000    1994.000000   1994.000000   1994.000000   1994.000000
# unique          NaN            NaN           NaN           NaN           NaN
# top             NaN            NaN           NaN           NaN           NaN
# freq            NaN            NaN           NaN           NaN           NaN
# mean       0.057593       0.463395      0.179629      0.753716      0.153681
# std        0.126906       0.163717      0.253442      0.244039      0.208877
# min        0.000000       0.000000      0.000000      0.000000      0.000000
# 25%        0.010000       0.350000      0.020000      0.630000      0.040000
# 50%        0.020000       0.440000      0.060000      0.850000      0.070000
# 75%        0.050000       0.540000      0.230000      0.940000      0.170000
# max        1.000000       1.000000      1.000000      1.000000      1.000000
#
#         ...  PolicAveOTWorked     LandArea      PopDens  PctUsePubTrans  \
# count   ...              1994  1994.000000  1994.000000     1994.000000
# unique  ...                78          NaN          NaN             NaN
# top     ...                 ?          NaN          NaN             NaN
# freq    ...              1675          NaN          NaN             NaN
# mean    ...               NaN     0.065231     0.232854        0.161685
# std     ...               NaN     0.109459     0.203092        0.229055
# min     ...               NaN     0.000000     0.000000        0.000000
# 25%     ...               NaN     0.020000     0.100000        0.020000
# 50%     ...               NaN     0.040000     0.170000        0.070000
# 75%     ...               NaN     0.070000     0.280000        0.190000
# max     ...               NaN     1.000000     1.000000        1.000000
#
#         PolicCars  PolicOperBudg  LemasPctPolicOnPatr  LemasGangUnitDeploy  \
# count        1994           1994                 1994                 1994
# unique         64             39                   73                    4
# top             ?              ?                    ?                    ?
# freq         1675           1675                 1675                 1675
# mean          NaN            NaN                  NaN                  NaN
# std           NaN            NaN                  NaN                  NaN
# min           NaN            NaN                  NaN                  NaN
# 25%           NaN            NaN                  NaN                  NaN
# 50%           NaN            NaN                  NaN                  NaN
# 75%           NaN            NaN                  NaN                  NaN
# max           NaN            NaN                  NaN                  NaN
#
#         LemasPctOfficDrugUn  PolicBudgPerPop
# count           1994.000000             1994
# unique                  NaN               52
# top                     NaN                ?
# freq                    NaN             1675
# mean               0.094052              NaN
# std                0.240328              NaN
# min                0.000000              NaN
# 25%                0.000000              NaN
# 50%                0.000000              NaN
# 75%                0.000000              NaN
# max                1.000000              NaN
#
# [11 rows x 127 columns]

# %%
y
# Out:
#       ViolentCrimesPerPop
# 0                    0.20
# 1                    0.67
# 2                    0.43
# 3                    0.12
# 4                    0.03
# ...                   ...
# 1989                 0.09
# 1990                 0.45
# 1991                 0.23
# 1992                 0.19
# 1993                 0.48
#
# [1994 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size = 0.4, 
                                                    random_state = 42)

# %% [markdown]
# <h1>Check Logistic regression for imbalanced data handling</h1>
